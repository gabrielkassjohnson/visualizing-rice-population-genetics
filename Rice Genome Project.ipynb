# %%
ls
# Out:
# 'Rice Genome Project.ipynb'
#  RICE_RP.tar.gz
# 'snp3kvars-CHR1-1-10000-841820070974764979(AusChr10allsnps1-10000).csv'
#  snp3kvars-LOC_OS11G01010-168161704215689027.csv
#  Untitled.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv("snp3kvars-LOC_OS11G01010-168161704215689027.csv")

# %%
df2 = pd.read_csv("snp3kvars-CHR1-1-10000-841820070974764979(AusChr10allsnps1-10000).csv")

# %%
df2
# Out:
#                          JAPONICA NIPPONBARE POSITIONS        ASSAY ID  \
# 0                          JAPONICA NIPPONBARE ALLELES             NaN
# 1    MSU7 EFFECTS (cds-Non-synonymous/cds-Synonymou...             NaN
# 2              UPRH 33::IRGC 61505-1::[IRIS 313-11617]  IRIS 313-11617
# 3            ARC 12920::IRGC 22450-1::[IRIS 313-10892]  IRIS 313-10892
# 4            ARC 11276::IRGC 21278-1::[IRIS 313-10861]  IRIS 313-10861
# ..                                                 ...             ...
# 198           DHAN 263::IRGC 27926-2::[IRIS 313-11025]  IRIS 313-11025
# 199           BORO 394::IRGC 29297-2::[IRIS 313-11065]  IRIS 313-11065
# 200       KALIBORO 600::IRGC 29367-1::[IRIS 313-11067]  IRIS 313-11067
# 201          ARC 11822::IRGC 21677-1::[IRIS 313-10873]  IRIS 313-10873
# 202         BENA JHUPI::IRGC 34850-2::[IRIS 313-11165]  IRIS 313-11165
#
#        ACCESSION SUBPOPULATION  MISMATCH 1026 1033 1038 1045 1047  ...  \
# ...
